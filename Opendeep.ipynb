# %% [markdown]
# <a href="https://colab.research.google.com/github/amalsalilan/Infosys-Springboard-Virtual-Internship-6.0-Open-Deep-Researcher-batch-2/blob/Tejas_V/Opendeep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install required packages (run once)
# !pip install -q google-generativeai langgraph langchain langchain-google-genai tavily-python python-dotenv

# %%
# 2. Imports & API setup
import os
import time
from typing import TypedDict, List

from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import ChatPromptTemplate
from langgraph.graph import StateGraph, END
from tavily import TavilyClient

# Load secrets from Colab
os.environ["GOOGLE_API_KEY"]  = userdata.get('GOOGLE_API_KEY')
os.environ["TAVILY_API_KEY"]  = userdata.get('TAVILY_API_KEY')

# Initialize LLM and Search client
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0.7)
tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
# 3. Define state and initialization
class ResearchState(TypedDict):
    original_query: str
    sub_questions: List[str]
    search_results: List[dict]
    synthesized_report: str
    current_step: str

def initialize_research(query: str) -> ResearchState:
    return ResearchState(
        original_query=query,
        sub_questions=[],
        search_results=[],
        synthesized_report="",
        current_step="initialized"
    )

# %%
# 4. Planner Agent with user selection
def planner_agent(state: ResearchState) -> ResearchState:
    print("\n🧠 PLANNER AGENT")
    planning_prompt = ChatPromptTemplate.from_messages([
        ("system", """You are a research planning expert. Break down the user's question into 3–5 focused sub-questions, one per line, numbered."""),
        ("user", "Main research question: {query}")
    ])
    chain = planning_prompt | llm
    response = chain.invoke({"query": state["original_query"]})

    # Parse auto-generated sub-questions
    candidates = []
    for line in response.content.strip().split("\n"):
        line = line.strip()
        if line and (line[0].isdigit() or line.startswith("-")):
            q = line.split(".",1)[-1].lstrip("-").strip()
            if q: candidates.append(q)
    if not candidates:
        candidates = [state["original_query"]]

    # Display and let user choose/edit
    print("\nAuto-generated sub-questions:")
    for i, q in enumerate(candidates,1):
        print(f"  {i}. {q}")
    print("\nEnter the numbers of the ones you want (comma-separated),")
    print("or type new/edited questions one per line, ending with an empty line.")

    choice = input("Selection or new questions: ").strip()
    chosen = []
    if all(ch.isdigit() or ch in ", " for ch in choice):
        for idx in choice.split(","):
            idx = idx.strip()
            if idx.isdigit() and 1 <= int(idx) <= len(candidates):
                chosen.append(candidates[int(idx)-1])
    else:
        print("Enter your custom sub-questions. Submit an empty line to finish.")
        while True:
            line = input().strip()
            if not line: break
            chosen.append(line)
    # Fallback
    if not chosen:
        chosen = candidates[:3]

    state["sub_questions"] = chosen
    state["current_step"] = "planning_complete"
    print(f"\n✅ Using {len(chosen)} sub-questions:")
    for i, q in enumerate(chosen,1):
        print(f"  {i}. {q}")
    return state

# %%
# 5. Searcher Agent
def searcher_agent(state: ResearchState) -> ResearchState:
    print("\n🔍 SEARCHER AGENT")
    results = []
    for i, q in enumerate(state["sub_questions"],1):
        print(f" [{i}/{len(state['sub_questions'])}] Searching: {q}")
        time.sleep(0.5)
        try:
            resp = tavily_client.search(query=q, search_depth="basic", max_results=3)
            for r in resp.get("results",[]):
                results.append({
                    "question": q,
                    "title": r.get("title",""),
                    "url": r.get("url",""),
                    "content": r.get("content","")[:800]
                })
        except Exception as e:
            print(f"  ⚠️ Error: {e}")
    state["search_results"] = results or [{
        "question":state["original_query"],
        "title":"No results","url":"","content":"No data"
    }]
    state["current_step"]="search_complete"
    return state

# %%
# 6. Writer Agent
def writer_agent(state: ResearchState) -> ResearchState:
    print("\n✍️ WRITER AGENT")
    context = "\n\n".join(
        f"[Source {i+1}] ({r['question']})\nTitle: {r['title']}\n{r['content']}\nURL: {r['url']}"
        for i,r in enumerate(state["search_results"])
    )
    prompt = ChatPromptTemplate.from_messages([
        ("system", """You are a research writer. Synthesize the info into a markdown report with:
1. Introduction
2. Main Findings by sub-question
3. Key Insights
4. Conclusion
5. Sources (use [Source X] citations)"""),
        ("user", """Original question: {query}

Sub-questions:
{sub_questions}

Data:
{context}

Write the report now in markdown.""")
    ])
    chain = prompt | llm
    resp = chain.invoke({
        "query":state["original_query"],
        "sub_questions":"\n".join(f"- {q}" for q in state["sub_questions"]),
        "context":context
    })
    state["synthesized_report"] = resp.content
    state["current_step"]="complete"
    return state

# %%
# 1. Clarify Agent: ask user to refine main query scope
def clarify_agent(state):
    print("\n🔍 CLARIFY AGENT")
    print("Please provide any additional context or constraints for your research question.")
    print("For example: specify time period, geographic region, target audience, or topic focus.")
    extra = input("Additional context (or press Enter to skip): ").strip()
    if extra:
        state["original_query"] += f" ({extra})"
        print(f"✅ Query refined to: {state['original_query']}")
    else:
        print("✅ No additional context provided.")
    state["current_step"] = "clarify_complete"
    return state

# %%
# 2. Scoping Agent: narrow down or confirm sub-question scope
def scoping_agent(state):
    print("\n🎯 SCOPING AGENT")
    print("Review the planned sub-questions and optionally narrow them by keyword or topic.")
    print("Enter keywords to filter sub-questions, or press Enter to keep all.")
    keywords = input("Scope keywords (comma-separated): ").strip().lower().split(",")
    if any(k.strip() for k in keywords):
        filtered = []
        for q in state["sub_questions"]:
            if any(k.strip() in q.lower() for k in keywords):
                filtered.append(q)
        if filtered:
            state["sub_questions"] = filtered
            print(f"✅ Sub-questions scoped to {len(filtered)} items.")
        else:
            print("⚠️ No sub-questions matched—keeping original list.")
    else:
        print("✅ No scoping applied; all sub-questions retained.")
    state["current_step"] = "scoping_complete"
    return state

# %%
# 3. Update pipeline to include clarify and scoping before planning & searching
def create_research_app_with_clarify():
    g = StateGraph(ResearchState)
    g.add_node("clarify", clarify_agent)
    g.add_node("planner", planner_agent)
    g.add_node("scoping", scoping_agent)
    g.add_node("searcher", searcher_agent)
    g.add_node("writer", writer_agent)
    g.set_entry_point("clarify")
    g.add_edge("clarify", "planner")   # Clarify → Planner
    g.add_edge("planner", "scoping")   # Planner → Scoping
    g.add_edge("scoping", "searcher")  # Scoping → Searcher
    g.add_edge("searcher", "writer")   # Searcher → Writer
    g.add_edge("writer", END)          # Writer → End
    return g.compile()

research_app = create_research_app_with_clarify()

# %%
# 4. Reflection Step: ask user for feedback after report
def reflect_with_user(final_state):
    print("\n💭 REFLECTION")
    print("Please review the report and answer:")
    print("1. Were the sub-questions relevant and comprehensive?")
    print("2. Is any key aspect missing?")
    print("3. How would you improve the report or add detail?")
    answers = []
    for question in [
        "1. Relevance/completeness of sub-questions?",
        "2. Missing aspects?",
        "3. Improvements or additions?"
    ]:
        ans = input(f"{question}\n> ").strip()
        answers.append(ans or "No comment")
    # Attach reflections to state
    final_state["reflection"] = answers
    print("\n✅ Thank you for your feedback!")
    return final_state

# %%
# 5. Main entry point, now including reflection
def start_research_with_clarify():
    print("\n=== OpenDeepResearcher with Clarify & Reflection ===")
    q = input("Enter your research question: ").strip()
    state = initialize_research(q)
    final = research_app.invoke(state)
    print("\n=== Research Report ===\n")
    print(final["synthesized_report"])
    final = reflect_with_user(final)
    # Optionally save reflections
    print("\nYour reflections:", final.get("reflection", []))

# Run the enhanced workflow
start_research_with_clarify()
# Out:
# === OpenDeepResearcher with Clarify & Reflection ===
# Enter your research question: which is the best laptop
#
# 🔍 CLARIFY AGENT
# Please provide any additional context or constraints for your research question.
# For example: specify time period, geographic region, target audience, or topic focus.
# Additional context (or press Enter to skip): india,gamers
# ✅ Query refined to: which is the best laptop (india,gamers)
#
# 🧠 PLANNER AGENT
#
# Auto-generated sub-questions:
#   1. What are the most important hardware specifications for gaming laptops in India (e.g., CPU, GPU, RAM, storage, display)?
#   2. What are the top-rated gaming laptop brands and models currently available in the Indian market, considering different price points?
#   3. What are the common issues or complaints reported by gamers in India regarding specific laptop models or brands?
#   4. How do factors like cooling solutions, battery life, and display quality impact the overall gaming experience on laptops in the Indian climate?
#   5. What are the current pricing trends and availability of gaming laptops in India, including online and offline retailers?
#
# Enter the numbers of the ones you want (comma-separated),
# or type new/edited questions one per line, ending with an empty line.
# Selection or new questions: 1,2,5
#
# ✅ Using 3 sub-questions:
#   1. What are the most important hardware specifications for gaming laptops in India (e.g., CPU, GPU, RAM, storage, display)?
#   2. What are the top-rated gaming laptop brands and models currently available in the Indian market, considering different price points?
#   3. What are the current pricing trends and availability of gaming laptops in India, including online and offline retailers?
#
# 🎯 SCOPING AGENT
# Review the planned sub-questions and optionally narrow them by keyword or topic.
# Enter keywords to filter sub-questions, or press Enter to keep all.
# Scope keywords (comma-separated): gpu,ram,price
# ✅ Sub-questions scoped to 2 items.
#
# 🔍 SEARCHER AGENT
#  [1/2] Searching: What are the most important hardware specifications for gaming laptops in India (e.g., CPU, GPU, RAM, storage, display)?
#  [2/2] Searching: What are the top-rated gaming laptop brands and models currently available in the Indian market, considering different price points?
#
# ✍️ WRITER AGENT
#
# === Research Report ===
#
# ## Gaming Laptops in India: A 2025 Buyer's Guide
#
# ### 1. Introduction
#
# The Indian gaming laptop market is rapidly evolving, presenting a wide array of options for gamers with varying budgets and performance needs. This report aims to provide a comprehensive overview of the key hardware specifications and top-rated gaming laptop brands and models currently available in India (as of 2025). By synthesizing information from various sources, this guide will assist gamers in making informed decisions when purchasing a gaming laptop.
#
# ### 2. Main Findings
#
# #### 2.1. What are the most important hardware specifications for gaming laptops in India?
#
# Several hardware components are crucial for a smooth and immersive gaming experience on a laptop. These include:
#
# *   **Processor (CPU):** The CPU is the brain of the laptop, responsible for processing instructions and running the game's logic. A high-performance CPU is essential to avoid bottlenecks and maintain stable frame rates [Source 1]. Top-tier CPUs like Intel Core i9 or AMD Ryzen 9 are recommended [Source 2].
# *   **Graphics Card (GPU):** The GPU is responsible for rendering the game's visuals. A powerful GPU is crucial for achieving high frame rates and visual fidelity. NVIDIA RTX 40/50 series cards are considered top-tier options [Source 2]. Upgrading the GPU is impossible in laptops [Source 3].
# *   **RAM (Memory):** Sufficient RAM is necessary for running games and other applications smoothly. 16GB of DDR5 RAM is now standard [Source 4].
# *   **Storage:** A fast storage solution, such as an SSD (Solid State Drive), is essential for quick game loading times and overall system responsiveness [Source 1].
# *   **Display:** A high refresh rate display (144Hz or higher) is crucial for a smooth and responsive gaming experience [Source 2].
# *   **Battery Life & Cooling:** Efficient cooling systems are essential to prevent overheating during intense gaming sessions. Longer battery life is also desirable for on-the-go gaming [Source 1].
#
# #### 2.2. What are the top-rated gaming laptop brands and models currently available in the Indian market, considering different price points?
#
# Several brands dominate the Indian gaming laptop market. These include:
#
# *   ASUS [Source 5]
# *   HP [Source 5]
# *   Dell [Source 5]
# *   Lenovo [Source 5]
# *   Acer [Source 5]
#
# Specific models mentioned include:
#
# *   HP Victus AI Powered AMD Ryzen 7 [Source 4]
# *   Razer Blade 18 (2024) [Source 6]
# *   Dell Alienware m18 R2 (2024) [Source 6]
#
# It's important to note that the "best" laptop is subjective and depends on individual needs and budget.
#
# ### 3. Key Insights
#
# *   **Component Upgrade Limitations:** Unlike desktop PCs, gaming laptops have limited upgradeability. The GPU and CPU are typically fixed, with only RAM and SSD being upgradable [Source 3].
# *   **Brand Credibility:** Established brands like ASUS, HP, Dell, Lenovo, and Acer offer a greater sense of reliability and customer support [Source 5].
# *   **Performance vs. Portability:** Gamers must balance performance with portability. High-end gaming laptops can be bulky and have shorter battery life.
# *   **Emerging Technologies:** AI-powered features, as seen in the HP Victus model, are becoming increasingly prevalent in gaming laptops [Source 4].
#
# ### 4. Conclusion
#
# Choosing the best gaming laptop in India requires careful consideration of hardware specifications, brand reputation, and budget. Focusing on a powerful CPU and GPU, ample RAM, and a fast SSD are crucial for a smooth gaming experience. While brands like ASUS, HP, Dell, Lenovo, and Acer are popular choices, the specific model should be selected based on individual needs and preferences.
#
# ### 5. Sources
#
# *   [Source 1] ABCom. "Best Laptop Configuration for Gaming in 2025 | ABCom." *rent.abcom.in*, [https://rent.abcom.in/how-to-choose-the-right-configuration-of-laptop-for-gaming-in-2025](https://rent.abcom.in/how-to-choose-the-right-configuration-of-laptop-for-gaming-in-2025)
# *   [Source 2] The Daily Jagran. "The 9 Best Gaming Laptops in 2025: India's Top Models for Pros to ..." *thedailyjagran.com*, [https://www.thedailyjagran.com/smart-guide/gadget-zone/the-best-gaming-laptops-indias-top-models-for-pros-to-beginners-6163](https://www.thedailyjagran.com/smart-guide/gadget-zone/the-best-gaming-laptops-indias-top-models-for-pros-to-beginners-6163)
# *   [Source 3] Digibuggy. "Gaming Laptop vs Gaming Desktop in India (2025 Guide & Price ..." *digibuggy.com*, [https://digibuggy.com/blog-details/gaming-laptop-vs-gaming-desktop-in-india-2025-guide-price-comparison](https://digibuggy.com/blog-details/gaming-laptop-vs-gaming-desktop-in-india-2025-guide-price-comparison)
# *   [Source 4] Hemant Kalwani. "Gaming Computer Laptop in India (Top 10 To Buy In 2025)" *hemantkalwani.com*, [https://hemantkalwani.com/laptops/gaming-computer-laptop-in-india/](https://hemantkalwani.com/laptops/gaming-computer-laptop-in-india/)
# *   [Source 5] Redington Blog. "Best Gaming Laptop in India 2025 - Redington Blog." *blog.redingtononline.com*, [https://blog.redingtononline.com/best-gaming-laptop-for-retailers-and-partners-a-2025-buyers-guide/](https://blog.redingtononline.com/best-gaming-laptop-for-retailers-and-partners-a-2025-buyers-guide/)
# *   [Source 6] RTINGS.com. "The 6 Best Gaming Laptops of 2025 - RTINGS.com." *rtings.com*, [https://www.rtings.com/laptop/reviews/best/by-usage/gaming](https://www.rtings.com/laptop/reviews/best/by-usage/gaming)
#
# 💭 REFLECTION
# Please review the report and answer:
# 1. Were the sub-questions relevant and comprehensive?
# 2. Is any key aspect missing?
# 3. How would you improve the report or add detail?
# 1. Relevance/completeness of sub-questions?
# > 1
# 2. Missing aspects?
# > price
# 3. Improvements or additions?
# > 16 inch
#
# ✅ Thank you for your feedback!
#
# Your reflections: ['1', 'price', '16 inch']
